# %% [markdown]
# # Análisis de los datos obtenidos de las simulaciones

# %%
from matplotlib.pyplot import subplots
import pandas as pd

# %%
datos = pd.read_csv("Resultados.csv")
datos
# Out:
#      Día      Oro    SP500   NVIDIA  Portafolio
# 0      0  2000.00  7600.00  300.000    100000.0
# 1      1  2000.59  7596.75  299.735     99960.7
# 2      2  1999.42  7598.70  300.650    100073.0
# 3      3  1998.72  7597.25  301.764    100205.0
# 4      4  1997.93  7595.49  302.506    100285.0
# ..   ...      ...      ...      ...         ...
# 247  247  2102.93  8167.65  373.260    113553.0
# 248  248  2105.59  8169.06  373.652    113650.0
# 249  249  2107.53  8170.40  374.186    113756.0
# 250  250  2107.66  8169.80  373.244    113630.0
# 251  251  2107.70  8167.85  373.633    113675.0
#
# [252 rows x 5 columns]

# %%
datos = datos.set_index('Día')
# Out:
#          Oro    SP500   NVIDIA  Portafolio
# Día
# 0    2000.00  7600.00  300.000    100000.0
# 1    2000.59  7596.75  299.735     99960.7
# 2    1999.42  7598.70  300.650    100073.0
# 3    1998.72  7597.25  301.764    100205.0
# 4    1997.93  7595.49  302.506    100285.0
# ..       ...      ...      ...         ...
# 247  2102.93  8167.65  373.260    113553.0
# 248  2105.59  8169.06  373.652    113650.0
# 249  2107.53  8170.40  374.186    113756.0
# 250  2107.66  8169.80  373.244    113630.0
# 251  2107.70  8167.85  373.633    113675.0
#
# [252 rows x 4 columns]

# %%
columnas_a_graficar = datos.columns  # todas las columnas
n_columnas = len(columnas_a_graficar)

# Crear subgráficas en disposición vertical
fig, axes = subplots(n_columnas, 1, figsize=(10, 4*n_columnas), sharex=True)

# Si solo hay una columna, axes no es una lista
if n_columnas == 1:
    axes = [axes]

for i, columna in enumerate(columnas_a_graficar):
    axes[i].plot(datos[columna], label=columna, color=f'C{i}')
    axes[i].set_ylabel(columna, fontsize=10)
    axes[i].legend(loc='upper right')
    axes[i].grid(True, alpha=0.3)
    
fig.suptitle('Variación diaria por activo', fontsize=14)
# Out:
# Text(0.5, 0.98, 'Variación diaria por activo')
